# %%
import numpy as np

p = 32.45
path = "/ibira/lnls/beamlines/caterete/proposals/20210160/proc/recons/glass21/Phase_glass21_reconstruction3D_EEM_equalized.npy"
a = np.load(path)

# %%
a.shape
# Out:
# (608, 558, 558)

# %%
import matplotlib.pyplot as plt

a[a.shape[0]//2,a.shape[1]//2,:].shape
# Out:
# (558,)

# %%
plt.plot(a[a.shape[0]//2,a.shape[1]//2,:][110:430])

# %%
(430-110)*p/1000
# Out:
# 10.384
